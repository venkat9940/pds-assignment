# %%
import pandas
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data_frame = pandas.read_csv('../data_clean/clean_frailty.csv', index_col=0)

# %%
ax = sns.heatmap(data_frame.corr(), cmap="YlGnBu", linewidths = 0.30, annot = True)
fig = ax.get_figure()
fig.savefig("../results/heatmap_Grip_Strength_Distribution.png")
